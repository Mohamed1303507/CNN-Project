# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator


#import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

#print(os.listdir("E:/Books/archive"))
#print(os.listdir("E:/Books/archiveskin-cancer-mnist-ham10000/"))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#read metadata
df_skin = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')

df_skin.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-dcf5594f4299> in <cell line: 2>()
#       1 #read metadata
# ----> 2 df_skin = pd.read_csv('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv')
#       3
#       4 df_skin.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_metadata.csv'

# %%
# lesion names are given in the description of the challenge
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

lesion_ID_dict = {
    'nv': 0,
    'mel': 1,
    'bkl': 2,
    'bcc': 3,
    'akiec': 4,
    'vasc': 5,
    'df': 6
}

lesion_names = ['Melanocytic nevi','Melanoma','Benign keratosis-like lesions ',
               'Basal cell carcinoma','Actinic keratoses','Vascular lesions',
               'Dermatofibroma']

lesion_names_short = ['nv','mel','bkl','bcc','akiec','vasc','df']

df_skin['lesion_type']=df_skin['dx'].map(lesion_type_dict)
df_skin['lesion_ID'] = df_skin['dx'].map(lesion_ID_dict)

print('Total number of images',len(df_skin))
print('The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels')

df_skin['lesion_type'].value_counts()
# Out:
# Total number of images 10015
# The problem is unbalanced, since Melanocytic nevi is much more frequent that other labels
# Melanocytic nevi                  6705
# Melanoma                          1113
# Benign keratosis-like lesions     1099
# Basal cell carcinoma               514
# Actinic keratoses                  327
# Vascular lesions                   142
# Dermatofibroma                     115
# Name: lesion_type, dtype: int64

# %%
# read the first image
fname_images = np.array(df_skin['image_id'])
file_to_read ='/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/'+str(fname_images[0])+'.jpg'

import cv2
from cv2 import imread, resize

img = imread(file_to_read)
img2 = resize(img,(100,100))

# show one exampe image

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img[:,:,::-1])
plt.title('Original image')
plt.subplot(1,2,2)
plt.imshow(img2[:,:,::-1])
plt.title('Resized image for DenseNet')
plt.show()

# %%
def produce_new_img(img2):
    # produce new images by rotating of flipping the original one
    # this helps to increase the dimension of the dataset, avoiding overfitting of a single class
    imga = cv2.rotate(img2,cv2.ROTATE_90_CLOCKWISE)
    imgb = cv2.rotate(img2,cv2.ROTATE_90_COUNTERCLOCKWISE)
    imgc = cv2.rotate(img2,cv2.ROTATE_180)
    imgd = cv2.flip(img2,0)
    imge = cv2.flip(img2,1)
    return imga,imgb,imgc,imgd,imge

new_img = produce_new_img(img2)

plt.figure(figsize=(10,8))
plt.subplot(2,3,1)
plt.imshow(img2[:,:,::-1])
for i in range(5):
    plt.subplot(2,3,2+i)
    plt.imshow(new_img[i][:,:,::-1])
plt.tight_layout()
plt.show()

# %%
# import images from 2 different folders

X = []
y = []

lista1 = os.listdir('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/')
lista2 = os.listdir('/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2/')


#import images from folder 1
for i in range(len(lista1)):
    fname_image = lista1[i]
    fname_ID = fname_image.replace('.jpg','')

    #features
    file_to_read ='/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_1/'+str(fname_image)
    img = imread(file_to_read)
    img2 = resize(img,(100,100))
    X.append(img2)

    #targets
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])

    # add more images for class between 1-6, rotating them
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            X.append(new_img[i])
            y.append(output[0])

    if i % int(100) == 0:
        print(i,'images loaded')

# import images from folder 2
for i in range(len(lista2)):
    fname_image = lista2[i]
    fname_ID = fname_image.replace('.jpg','')

    #features
    file_to_read ='/kaggle/input/skin-cancer-mnist-ham10000/HAM10000_images_part_2/'+str(fname_image)
    img = imread(file_to_read)
    img2 = resize(img,(100,100))
    X.append(img2)

    #targets
    output = np.array(df_skin[df_skin['image_id'] == fname_ID].lesion_ID)
    y.append(output[0])

    # add more images for class between 1-6
    if output != 0:
        new_img = produce_new_img(img2)
        for i in range(5):
            X.append(new_img[i])
            y.append(output[0])

    if i % int(100) == 0:

        print(len(lista1)+i,'images loaded')
# Out:
# 0 images loaded
# 100 images loaded
# 200 images loaded
# 300 images loaded
# 400 images loaded
# 500 images loaded
# 600 images loaded
# 700 images loaded
# 800 images loaded
# 1100 images loaded
# 1200 images loaded
# 1500 images loaded
# 1600 images loaded
# 1800 images loaded
# 2100 images loaded
# 2300 images loaded
# 2400 images loaded
# 2600 images loaded
# 2700 images loaded
# 2800 images loaded
# 2900 images loaded
# 3000 images loaded
# 3100 images loaded
# 3200 images loaded
# 3500 images loaded
# 3600 images loaded
# 3700 images loaded
# 3900 images loaded
# 4100 images loaded
# 4500 images loaded
# 4600 images loaded
# 4700 images loaded
# 4800 images loaded
# 4900 images loaded
# 5000 images loaded
# 5100 images loaded
# 5300 images loaded
# 5400 images loaded
# 5700 images loaded
# 5900 images loaded
# 6000 images loaded
# 6100 images loaded
# 6200 images loaded
# 6400 images loaded
# 6600 images loaded
# 6700 images loaded
# 6800 images loaded
# 6900 images loaded
# 7000 images loaded
# 7100 images loaded
# 7200 images loaded
# 7300 images loaded
# 7400 images loaded
# 7500 images loaded
# 7600 images loaded
# 7700 images loaded
# 7800 images loaded
# 8000 images loaded
# 8100 images loaded
# 8300 images loaded
# 8400 images loaded
# 8700 images loaded
# 8900 images loaded
# 9100 images loaded
# 9200 images loaded
# 9400 images loaded
# 9500 images loaded
# 9600 images loaded
# 9700 images loaded
# 9800 images loaded
# 9900 images loaded

# %%
from keras.utils.np_utils import to_categorical

X = np.array(X)
y = np.array(y)

y_train = to_categorical(y, num_classes=7)

# #convert targets in dummy variables, as required by softmax activation function
# y_dumm = np.array(pd.get_dummies(y))

# %%
from sklearn.model_selection import train_test_split

# split in 80% training and 20% test data
X_train, X_test, y_train, y_test = train_test_split(X, y_train, test_size=0.33, random_state=50,stratify=y)


print('Train dataset shape',X_train.shape)
print('Test dataset shape',X_test.shape)
# Out:
# Train dataset shape (17798, 100, 100, 3)
# Test dataset shape (8767, 100, 100, 3)

# %%
fig, ax = plt.subplots(1, 7, figsize=(30, 30))
for i in range(7):
    ax[i].set_axis_off()
    ax[i].imshow(X_train[i])
    ax[i].set_title(lesion_names[np.argmax(y_train[i])])

# %%
import keras
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping,ModelCheckpoint
from keras.layers.core import Dropout, Activation
from keras.layers import Conv2D,BatchNormalization,MaxPool2D,Flatten,Dense

# %%
from sklearn.utils.class_weight import compute_class_weight
y_id = np.array(df_skin['lesion_ID'])

# compute weights for the loss function, because the problem is unbalanced
class_weights = np.around(compute_class_weight(class_weight='balanced',classes=np.unique(y_id),y=y),2)
class_weights = dict(zip(np.unique(y_id),class_weights))

print('The problem is unbalanced. We need to provide class_weights ')
print(class_weights)
# Out:
# The problem is unbalanced. We need to provide class_weights
# {0: 0.57, 1: 0.57, 2: 0.58, 3: 1.23, 4: 1.93, 5: 4.45, 6: 5.5}

# %%
# building Neural Network

import keras
from keras.models import Model
from keras.layers import Conv2D, MaxPooling2D, Dense, Input, Activation, Dropout, GlobalAveragePooling2D, \
    BatchNormalization, concatenate, AveragePooling2D
from keras.optimizers import Adam

model = Sequential([

    # 1st convolutional layer
    Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(100,100,3)),
    BatchNormalization(),
    MaxPool2D(pool_size=(3,3), strides=(2,2)),

    # 2nd convolutional layer
    Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    BatchNormalization(),
    MaxPool2D(pool_size=(3,3), strides=(2,2)),

    # 3rd convolutional layer
    Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    BatchNormalization(),

    # 4th convolutional layer
    Conv2D(filters=384, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    BatchNormalization(),

    # 5th convolutional layer
    Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    BatchNormalization(),
    MaxPool2D(pool_size=(3,3), strides=(2,2)),

    Flatten(),

    # 6th, Dense layer
    Dense(4096, activation='relu'),
    Dropout(0.5),

    # 7th Dense layer
    Dense(4096, activation='relu'),
    Dropout(0.5),

    # 8th output layer
    Dense(7, activation='softmax')
])

# %%
# training
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

early_stopping_monitor = EarlyStopping(patience=100,monitor='val_accuracy')
model_checkpoint_callback = ModelCheckpoint(filepath='model.h5',
                                            save_weights_only=False,
                                            monitor='val_accuracy',
                                            mode='auto',
                                            save_best_only=True,
                                            verbose=1)
batch_size = 32
epochs = 100
optimizer = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-3)
model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics=['accuracy'])

datagen = ImageDataGenerator(zoom_range = 0.2, horizontal_flip=True, shear_range=0.2)

datagen.fit(X_train)

history=model.fit(datagen.flow(X_train,y_train), epochs=epochs, batch_size=batch_size, shuffle=True, callbacks=[early_stopping_monitor,model_checkpoint_callback], validation_data=(X_test, y_test), class_weight=class_weights)
# Out:
# Epoch 1/100
# 557/557 [==============================] - 44s 73ms/step - loss: 1.9491 - accuracy: 0.3445 - val_loss: 2.1044 - val_accuracy: 0.2749
#
# Epoch 00001: val_accuracy improved from -inf to 0.27489, saving model to model.h5
# Epoch 2/100
# 557/557 [==============================] - 40s 72ms/step - loss: 1.3270 - accuracy: 0.4875 - val_loss: 1.9979 - val_accuracy: 0.2781
#
# Epoch 00002: val_accuracy improved from 0.27489 to 0.27809, saving model to model.h5
# Epoch 3/100
# 557/557 [==============================] - 41s 73ms/step - loss: 1.1981 - accuracy: 0.5141 - val_loss: 1.8699 - val_accuracy: 0.2828
#
# Epoch 00003: val_accuracy improved from 0.27809 to 0.28276, saving model to model.h5
# Epoch 4/100
# 557/557 [==============================] - 41s 73ms/step - loss: 1.1080 - accuracy: 0.5446 - val_loss: 1.2588 - val_accuracy: 0.4508
#
# Epoch 00004: val_accuracy improved from 0.28276 to 0.45078, saving model to model.h5
# Epoch 5/100
# 557/557 [==============================] - 40s 72ms/step - loss: 1.0042 - accuracy: 0.5737 - val_loss: 1.7714 - val_accuracy: 0.3898
#
# Epoch 00005: val_accuracy did not improve from 0.45078
# Epoch 6/100
# 557/557 [==============================] - 41s 73ms/step - loss: 0.9625 - accuracy: 0.5813 - val_loss: 2.6195 - val_accuracy: 0.3340
#
# Epoch 00006: val_accuracy did not improve from 0.45078
# Epoch 7/100
# 557/557 [==============================] - 41s 73ms/step - loss: 0.9506 - accuracy: 0.5933 - val_loss: 1.5201 - val_accuracy: 0.4301
#
# Epoch 00007: val_accuracy did not improve from 0.45078
# Epoch 8/100
# 557/557 [==============================] - 41s 73ms/step - loss: 0.8686 - accuracy: 0.6018 - val_loss: 1.3048 - val_accuracy: 0.4898
#
# Epoch 00008: val_accuracy improved from 0.45078 to 0.48979, saving model to model.h5
# Epoch 9/100
# 557/557 [==============================] - 41s 74ms/step - loss: 0.8167 - accuracy: 0.6277 - val_loss: 1.2001 - val_accuracy: 0.5701
#
# Epoch 00009: val_accuracy improved from 0.48979 to 0.57009, saving model to model.h5
# Epoch 10/100
# 557/557 [==============================] - 42s 74ms/step - loss: 0.8021 - accuracy: 0.6359 - val_loss: 1.9457 - val_accuracy: 0.4126
#
# Epoch 00010: val_accuracy did not improve from 0.57009
# Epoch 11/100
# 557/557 [==============================] - 42s 75ms/step - loss: 0.7898 - accuracy: 0.6386 - val_loss: 2.1201 - val_accuracy: 0.3220
#
# Epoch 00011: val_accuracy did not improve from 0.57009
# Epoch 12/100
# 557/557 [==============================] - 41s 74ms/step - loss: 0.7653 - accuracy: 0.6444 - val_loss: 2.2547 - val_accuracy: 0.3142
#
# Epoch 00012: val_accuracy did not improve from 0.57009
# Epoch 13/100
# 557/557 [==============================] - 41s 74ms/step - loss: 0.7206 - accuracy: 0.6522 - val_loss: 2.8845 - val_accuracy: 0.3628
#
# Epoch 00013: val_accuracy did not improve from 0.57009
# Epoch 14/100
# 557/557 [==============================] - 42s 76ms/step - loss: 0.6928 - accuracy: 0.6659 - val_loss: 0.9637 - val_accuracy: 0.6332
#
# Epoch 00014: val_accuracy improved from 0.57009 to 0.63317, saving model to model.h5
# Epoch 15/100
# 557/557 [==============================] - 41s 74ms/step - loss: 0.6340 - accuracy: 0.6798 - val_loss: 1.4000 - val_accuracy: 0.4711
#
# Epoch 00015: val_accuracy did not improve from 0.63317
# Epoch 16/100
# 557/557 [==============================] - 42s 75ms/step - loss: 0.6645 - accuracy: 0.6799 - val_loss: 1.2243 - val_accuracy: 0.5737
#
# Epoch 00016: val_accuracy did not improve from 0.63317
# Epoch 17/100
# 557/557 [==============================] - 42s 75ms/step - loss: 0.6052 - accuracy: 0.7045 - val_loss: 1.4747 - val_accuracy: 0.4869
#
# Epoch 00017: val_accuracy did not improve from 0.63317
# Epoch 18/100
# 557/557 [==============================] - 44s 79ms/step - loss: 0.6008 - accuracy: 0.6960 - val_loss: 0.9234 - val_accuracy: 0.6463
#
# Epoch 00018: val_accuracy improved from 0.63317 to 0.64629, saving model to model.h5
# Epoch 19/100
# 557/557 [==============================] - 42s 75ms/step - loss: 0.5820 - accuracy: 0.7037 - val_loss: 1.8088 - val_accuracy: 0.4259
#
# Epoch 00019: val_accuracy did not improve from 0.64629
# Epoch 20/100
# 557/557 [==============================] - 42s 75ms/step - loss: 0.5477 - accuracy: 0.7154 - val_loss: 0.9220 - val_accuracy: 0.6564
#
# Epoch 00020: val_accuracy improved from 0.64629 to 0.65644, saving model to model.h5
# Epoch 21/100
# 557/557 [==============================] - 43s 76ms/step - loss: 0.5418 - accuracy: 0.7218 - val_loss: 2.0160 - val_accuracy: 0.5143
#
# Epoch 00021: val_accuracy did not improve from 0.65644
# Epoch 22/100
# 557/557 [==============================] - 45s 80ms/step - loss: 0.5016 - accuracy: 0.7354 - val_loss: 1.5798 - val_accuracy: 0.4799
#
# Epoch 00022: val_accuracy did not improve from 0.65644
# Epoch 23/100
# 557/557 [==============================] - 42s 76ms/step - loss: 0.5045 - accuracy: 0.7258 - val_loss: 1.9316 - val_accuracy: 0.4808
#
# Epoch 00023: val_accuracy did not improve from 0.65644
# Epoch 24/100
# 557/557 [==============================] - 44s 78ms/step - loss: 0.5042 - accuracy: 0.7402 - val_loss: 0.9766 - val_accuracy: 0.6597
#
# Epoch 00024: val_accuracy improved from 0.65644 to 0.65975, saving model to model.h5
# Epoch 25/100
# 557/557 [==============================] - 42s 76ms/step - loss: 0.4540 - accuracy: 0.7548 - val_loss: 0.8311 - val_accuracy: 0.6829
#
# Epoch 00025: val_accuracy improved from 0.65975 to 0.68290, saving model to model.h5
# Epoch 26/100
# 557/557 [==============================] - 43s 78ms/step - loss: 0.4493 - accuracy: 0.7561 - val_loss: 0.7645 - val_accuracy: 0.7078
#
# Epoch 00026: val_accuracy improved from 0.68290 to 0.70777, saving model to model.h5
# Epoch 27/100
# 557/557 [==============================] - 46s 82ms/step - loss: 0.4128 - accuracy: 0.7720 - val_loss: 1.0224 - val_accuracy: 0.6404
#
# Epoch 00027: val_accuracy did not improve from 0.70777
# Epoch 28/100
# 557/557 [==============================] - 43s 77ms/step - loss: 0.4090 - accuracy: 0.7778 - val_loss: 1.2217 - val_accuracy: 0.6145
#
# Epoch 00028: val_accuracy did not improve from 0.70777
# Epoch 29/100
# 557/557 [==============================] - 43s 78ms/step - loss: 0.4274 - accuracy: 0.7763 - val_loss: 1.4370 - val_accuracy: 0.5501
#
# Epoch 00029: val_accuracy did not improve from 0.70777
# Epoch 30/100
# 557/557 [==============================] - 43s 77ms/step - loss: 0.3848 - accuracy: 0.7886 - val_loss: 0.8995 - val_accuracy: 0.6772
#
# Epoch 00030: val_accuracy did not improve from 0.70777
# Epoch 31/100
# 557/557 [==============================] - 43s 78ms/step - loss: 0.3988 - accuracy: 0.7810 - val_loss: 1.1654 - val_accuracy: 0.5899
#
# Epoch 00031: val_accuracy did not improve from 0.70777
# Epoch 32/100
# 557/557 [==============================] - 43s 77ms/step - loss: 0.3808 - accuracy: 0.7921 - val_loss: 1.1895 - val_accuracy: 0.6347
#
# Epoch 00032: val_accuracy did not improve from 0.70777
# Epoch 33/100
# 557/557 [==============================] - 41s 73ms/step - loss: 0.3386 - accuracy: 0.8076 - val_loss: 0.7209 - val_accuracy: 0.7281
#
# Epoch 00033: val_accuracy improved from 0.70777 to 0.72807, saving model to model.h5
# Epoch 34/100
# 557/557 [==============================] - 44s 78ms/step - loss: 0.3977 - accuracy: 0.7985 - val_loss: 0.8062 - val_accuracy: 0.7110
#
# Epoch 00034: val_accuracy did not improve from 0.72807
# Epoch 35/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.3329 - accuracy: 0.8158 - val_loss: 1.4858 - val_accuracy: 0.6033
#
# Epoch 00035: val_accuracy did not improve from 0.72807
# Epoch 36/100
# 557/557 [==============================] - 44s 79ms/step - loss: 0.3371 - accuracy: 0.8118 - val_loss: 0.8393 - val_accuracy: 0.6885
#
# Epoch 00036: val_accuracy did not improve from 0.72807
# Epoch 37/100
# 557/557 [==============================] - 44s 79ms/step - loss: 0.3363 - accuracy: 0.8186 - val_loss: 3.1620 - val_accuracy: 0.4332
#
# Epoch 00037: val_accuracy did not improve from 0.72807
# Epoch 38/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.3366 - accuracy: 0.8117 - val_loss: 1.1783 - val_accuracy: 0.6344
#
# Epoch 00038: val_accuracy did not improve from 0.72807
# Epoch 39/100
# 557/557 [==============================] - 44s 80ms/step - loss: 0.3009 - accuracy: 0.8266 - val_loss: 0.6958 - val_accuracy: 0.7345
#
# Epoch 00039: val_accuracy improved from 0.72807 to 0.73446, saving model to model.h5
# Epoch 40/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.2960 - accuracy: 0.8287 - val_loss: 0.5966 - val_accuracy: 0.7811
#
# Epoch 00040: val_accuracy improved from 0.73446 to 0.78111, saving model to model.h5
# Epoch 41/100
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2862 - accuracy: 0.8387 - val_loss: 0.9861 - val_accuracy: 0.6626
#
# Epoch 00041: val_accuracy did not improve from 0.78111
# Epoch 42/100
# 557/557 [==============================] - 45s 81ms/step - loss: 0.2939 - accuracy: 0.8319 - val_loss: 1.0503 - val_accuracy: 0.6629
#
# Epoch 00042: val_accuracy did not improve from 0.78111
# Epoch 43/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.2945 - accuracy: 0.8389 - val_loss: 1.1513 - val_accuracy: 0.6335
#
# Epoch 00043: val_accuracy did not improve from 0.78111
# Epoch 44/100
# 557/557 [==============================] - 44s 80ms/step - loss: 0.2992 - accuracy: 0.8333 - val_loss: 0.7607 - val_accuracy: 0.7382
#
# Epoch 00044: val_accuracy did not improve from 0.78111
# Epoch 45/100
# 557/557 [==============================] - 40s 73ms/step - loss: 0.2768 - accuracy: 0.8490 - val_loss: 1.0337 - val_accuracy: 0.6811
#
# Epoch 00045: val_accuracy did not improve from 0.78111
# Epoch 46/100
# 557/557 [==============================] - 44s 79ms/step - loss: 0.2498 - accuracy: 0.8597 - val_loss: 2.6380 - val_accuracy: 0.4725
#
# Epoch 00046: val_accuracy did not improve from 0.78111
# Epoch 47/100
# 557/557 [==============================] - 45s 81ms/step - loss: 0.2526 - accuracy: 0.8553 - val_loss: 0.7207 - val_accuracy: 0.7435
#
# Epoch 00047: val_accuracy did not improve from 0.78111
# Epoch 48/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.2403 - accuracy: 0.8684 - val_loss: 1.0347 - val_accuracy: 0.6985
#
# Epoch 00048: val_accuracy did not improve from 0.78111
# Epoch 49/100
# 557/557 [==============================] - 45s 82ms/step - loss: 0.2612 - accuracy: 0.8549 - val_loss: 0.8063 - val_accuracy: 0.7188
#
# Epoch 00049: val_accuracy did not improve from 0.78111
# Epoch 50/100
# 557/557 [==============================] - 40s 71ms/step - loss: 0.2482 - accuracy: 0.8576 - val_loss: 0.5905 - val_accuracy: 0.7901
#
# Epoch 00050: val_accuracy improved from 0.78111 to 0.79012, saving model to model.h5
# Epoch 51/100
# 557/557 [==============================] - 46s 82ms/step - loss: 0.2257 - accuracy: 0.8692 - val_loss: 0.7577 - val_accuracy: 0.7432
#
# Epoch 00051: val_accuracy did not improve from 0.79012
# Epoch 52/100
# 557/557 [==============================] - 46s 82ms/step - loss: 0.2442 - accuracy: 0.8660 - val_loss: 0.6011 - val_accuracy: 0.7949
#
# Epoch 00052: val_accuracy improved from 0.79012 to 0.79491, saving model to model.h5
# Epoch 53/100
# 557/557 [==============================] - 39s 71ms/step - loss: 0.2403 - accuracy: 0.8659 - val_loss: 0.7752 - val_accuracy: 0.7362
#
# Epoch 00053: val_accuracy did not improve from 0.79491
# Epoch 54/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.2204 - accuracy: 0.8742 - val_loss: 0.4620 - val_accuracy: 0.8284
#
# Epoch 00054: val_accuracy improved from 0.79491 to 0.82845, saving model to model.h5
# Epoch 55/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.1969 - accuracy: 0.8850 - val_loss: 0.6563 - val_accuracy: 0.7762
#
# Epoch 00055: val_accuracy did not improve from 0.82845
# Epoch 56/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.2028 - accuracy: 0.8801 - val_loss: 1.2403 - val_accuracy: 0.6550
#
# Epoch 00056: val_accuracy did not improve from 0.82845
# Epoch 57/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.2045 - accuracy: 0.8884 - val_loss: 0.7985 - val_accuracy: 0.7483
#
# Epoch 00057: val_accuracy did not improve from 0.82845
# Epoch 58/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.2001 - accuracy: 0.8831 - val_loss: 0.9523 - val_accuracy: 0.7093
#
# Epoch 00058: val_accuracy did not improve from 0.82845
# Epoch 59/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.1817 - accuracy: 0.8939 - val_loss: 0.8097 - val_accuracy: 0.7524
#
# Epoch 00059: val_accuracy did not improve from 0.82845
# Epoch 60/100
# 557/557 [==============================] - 41s 73ms/step - loss: 0.2375 - accuracy: 0.8750 - val_loss: 1.3119 - val_accuracy: 0.6491
#
# Epoch 00060: val_accuracy did not improve from 0.82845
# Epoch 61/100
# 557/557 [==============================] - 46s 83ms/step - loss: 0.1787 - accuracy: 0.8975 - val_loss: 0.6059 - val_accuracy: 0.7888
#
# Epoch 00061: val_accuracy did not improve from 0.82845
# Epoch 62/100
# 557/557 [==============================] - 40s 71ms/step - loss: 0.1878 - accuracy: 0.8942 - val_loss: 0.4134 - val_accuracy: 0.8555
#
# Epoch 00062: val_accuracy improved from 0.82845 to 0.85548, saving model to model.h5
# Epoch 63/100
# 557/557 [==============================] - 40s 73ms/step - loss: 0.1695 - accuracy: 0.9007 - val_loss: 0.7499 - val_accuracy: 0.7507
#
# Epoch 00063: val_accuracy did not improve from 0.85548
# Epoch 64/100
# 557/557 [==============================] - 47s 84ms/step - loss: 0.1778 - accuracy: 0.9054 - val_loss: 1.0241 - val_accuracy: 0.7070
#
# Epoch 00064: val_accuracy did not improve from 0.85548
# Epoch 65/100
# 557/557 [==============================] - 40s 71ms/step - loss: 0.1888 - accuracy: 0.8959 - val_loss: 1.3527 - val_accuracy: 0.6653
#
# Epoch 00065: val_accuracy did not improve from 0.85548
# Epoch 66/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.1667 - accuracy: 0.9046 - val_loss: 0.5660 - val_accuracy: 0.8028
#
# Epoch 00066: val_accuracy did not improve from 0.85548
# Epoch 67/100
# 557/557 [==============================] - 47s 85ms/step - loss: 0.1456 - accuracy: 0.9156 - val_loss: 0.6042 - val_accuracy: 0.8003
#
# Epoch 00067: val_accuracy did not improve from 0.85548
# Epoch 68/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.1905 - accuracy: 0.9012 - val_loss: 0.3971 - val_accuracy: 0.8663
#
# Epoch 00068: val_accuracy improved from 0.85548 to 0.86632, saving model to model.h5
# Epoch 69/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.1931 - accuracy: 0.9004 - val_loss: 0.7011 - val_accuracy: 0.7780
#
# Epoch 00069: val_accuracy did not improve from 0.86632
# Epoch 70/100
# 557/557 [==============================] - 45s 81ms/step - loss: 0.1606 - accuracy: 0.9099 - val_loss: 1.1163 - val_accuracy: 0.6994
#
# Epoch 00070: val_accuracy did not improve from 0.86632
# Epoch 71/100
# 557/557 [==============================] - 42s 76ms/step - loss: 0.1571 - accuracy: 0.9117 - val_loss: 0.4275 - val_accuracy: 0.8575
#
# Epoch 00071: val_accuracy did not improve from 0.86632
# Epoch 72/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.1364 - accuracy: 0.9200 - val_loss: 0.4195 - val_accuracy: 0.8546
#
# Epoch 00072: val_accuracy did not improve from 0.86632
# Epoch 73/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.1338 - accuracy: 0.9245 - val_loss: 0.6290 - val_accuracy: 0.8042
#
# Epoch 00073: val_accuracy did not improve from 0.86632
# Epoch 74/100
# 557/557 [==============================] - 48s 86ms/step - loss: 0.1293 - accuracy: 0.9242 - val_loss: 0.9117 - val_accuracy: 0.7422
#
# Epoch 00074: val_accuracy did not improve from 0.86632
# Epoch 75/100
# 557/557 [==============================] - 40s 73ms/step - loss: 0.1503 - accuracy: 0.9150 - val_loss: 1.1984 - val_accuracy: 0.6933
#
# Epoch 00075: val_accuracy did not improve from 0.86632
# Epoch 76/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.1459 - accuracy: 0.9191 - val_loss: 0.4997 - val_accuracy: 0.8482
#
# Epoch 00076: val_accuracy did not improve from 0.86632
# Epoch 77/100
# 557/557 [==============================] - 48s 87ms/step - loss: 0.1196 - accuracy: 0.9303 - val_loss: 0.4256 - val_accuracy: 0.8605
#
# Epoch 00077: val_accuracy did not improve from 0.86632
# Epoch 78/100
# 557/557 [==============================] - 40s 73ms/step - loss: 0.1270 - accuracy: 0.9308 - val_loss: 0.5078 - val_accuracy: 0.8284
#
# Epoch 00078: val_accuracy did not improve from 0.86632
# Epoch 79/100
# 557/557 [==============================] - 40s 71ms/step - loss: 0.1418 - accuracy: 0.9217 - val_loss: 0.5418 - val_accuracy: 0.8162
#
# Epoch 00079: val_accuracy did not improve from 0.86632
# Epoch 80/100
# 557/557 [==============================] - 49s 88ms/step - loss: 0.1626 - accuracy: 0.9156 - val_loss: 2.0428 - val_accuracy: 0.5755
#
# Epoch 00080: val_accuracy did not improve from 0.86632
# Epoch 81/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.1542 - accuracy: 0.9183 - val_loss: 0.3367 - val_accuracy: 0.8884
#
# Epoch 00081: val_accuracy improved from 0.86632 to 0.88845, saving model to model.h5
# Epoch 82/100
# 557/557 [==============================] - 40s 71ms/step - loss: 0.1238 - accuracy: 0.9326 - val_loss: 1.4573 - val_accuracy: 0.6466
#
# Epoch 00082: val_accuracy did not improve from 0.88845
# Epoch 83/100
# 557/557 [==============================] - 44s 78ms/step - loss: 0.1758 - accuracy: 0.9115 - val_loss: 0.3569 - val_accuracy: 0.8834
#
# Epoch 00083: val_accuracy did not improve from 0.88845
# Epoch 84/100
# 557/557 [==============================] - 46s 82ms/step - loss: 0.1427 - accuracy: 0.9262 - val_loss: 0.5597 - val_accuracy: 0.8183
#
# Epoch 00084: val_accuracy did not improve from 0.88845
# Epoch 85/100
# 557/557 [==============================] - 40s 71ms/step - loss: 0.1143 - accuracy: 0.9387 - val_loss: 0.8092 - val_accuracy: 0.7645
#
# Epoch 00085: val_accuracy did not improve from 0.88845
# Epoch 86/100
# 557/557 [==============================] - 39s 71ms/step - loss: 0.1243 - accuracy: 0.9311 - val_loss: 0.8334 - val_accuracy: 0.7608
#
# Epoch 00086: val_accuracy did not improve from 0.88845
# Epoch 87/100
# 557/557 [==============================] - 50s 90ms/step - loss: 0.1115 - accuracy: 0.9362 - val_loss: 0.3478 - val_accuracy: 0.8868
#
# Epoch 00087: val_accuracy did not improve from 0.88845
# Epoch 88/100
# 557/557 [==============================] - 40s 71ms/step - loss: 0.1001 - accuracy: 0.9423 - val_loss: 0.9243 - val_accuracy: 0.7634
#
# Epoch 00088: val_accuracy did not improve from 0.88845
# Epoch 89/100
# 557/557 [==============================] - 40s 71ms/step - loss: 0.1143 - accuracy: 0.9398 - val_loss: 0.5431 - val_accuracy: 0.8322
#
# Epoch 00089: val_accuracy did not improve from 0.88845
# Epoch 90/100
# 557/557 [==============================] - 51s 91ms/step - loss: 0.1230 - accuracy: 0.9337 - val_loss: 0.5830 - val_accuracy: 0.8177
#
# Epoch 00090: val_accuracy did not improve from 0.88845
# Epoch 91/100
# 557/557 [==============================] - 40s 71ms/step - loss: 0.1175 - accuracy: 0.9354 - val_loss: 0.3291 - val_accuracy: 0.8939
#
# Epoch 00091: val_accuracy improved from 0.88845 to 0.89392, saving model to model.h5
# Epoch 92/100
# 557/557 [==============================] - 39s 71ms/step - loss: 0.1174 - accuracy: 0.9382 - val_loss: 0.4291 - val_accuracy: 0.8667
#
# Epoch 00092: val_accuracy did not improve from 0.89392
# Epoch 93/100
# 557/557 [==============================] - 45s 81ms/step - loss: 0.1121 - accuracy: 0.9370 - val_loss: 0.6395 - val_accuracy: 0.8007
#
# Epoch 00093: val_accuracy did not improve from 0.89392
# Epoch 94/100
# 557/557 [==============================] - 74s 132ms/step - loss: 0.1080 - accuracy: 0.9402 - val_loss: 0.4965 - val_accuracy: 0.8373
#
# Epoch 00094: val_accuracy did not improve from 0.89392
# Epoch 95/100
# 557/557 [==============================] - 84s 151ms/step - loss: 0.0986 - accuracy: 0.9481 - val_loss: 0.6100 - val_accuracy: 0.8029
#
# Epoch 00095: val_accuracy did not improve from 0.89392
# Epoch 96/100
# 557/557 [==============================] - 48s 85ms/step - loss: 0.1293 - accuracy: 0.9371 - val_loss: 0.4760 - val_accuracy: 0.8513
#
# Epoch 00096: val_accuracy did not improve from 0.89392
# Epoch 97/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.0932 - accuracy: 0.9471 - val_loss: 0.4920 - val_accuracy: 0.8445
#
# Epoch 00097: val_accuracy did not improve from 0.89392
# Epoch 98/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.0946 - accuracy: 0.9495 - val_loss: 0.3162 - val_accuracy: 0.9020
#
# Epoch 00098: val_accuracy improved from 0.89392 to 0.90202, saving model to model.h5
# Epoch 99/100
# 557/557 [==============================] - 40s 72ms/step - loss: 0.1173 - accuracy: 0.9436 - val_loss: 3.1451 - val_accuracy: 0.4802
#
# Epoch 00099: val_accuracy did not improve from 0.90202
# Epoch 100/100
# 557/557 [==============================] - 41s 73ms/step - loss: 0.1448 - accuracy: 0.9304 - val_loss: 0.6086 - val_accuracy: 0.8192
#
# Epoch 00100: val_accuracy did not improve from 0.90202

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# 274/274 [==============================] - 1s 4ms/step - loss: 0.6086 - accuracy: 0.8192
# Accuracy: 81.92%

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = model.predict(X_test)

total = 0
accurate = 0
accurateindex = []
wrongindex = []

for i in range(len(y_pred)):
    if np.argmax(y_pred[i]) == np.argmax(y_test[i]):
        accurate += 1
        accurateindex.append(i)
    else:
        wrongindex.append(i)

    total += 1

print('Total-test-data;', total, '\taccurately-predicted-data:', accurate, '\t wrongly-predicted-data: ', total - accurate)

print('Accuracy:', round(accurate/total*100, 3), '%')
# Out:
# Total-test-data; 8767 	accurately-predicted-data: 7182 	 wrongly-predicted-data:  1585
# Accuracy: 81.921 %

# %%
best_model = load_model('model.h5')

# compute predictions
y_pred_prob = np.around(best_model.predict(X_test),3)
y_pred = np.argmax(y_pred_prob,axis=1)

y_test2 = np.argmax(y_test,axis=1)

# %%
plt.figure(figsize=(16,16))
for i in range(16):
    plt.subplot(4,4,i+1)
    index = i+100
    plt.imshow(X_test[index,:,:,::-1])
    label_exp = lesion_names[y_test2[index]]  #expected label
    label_pred = lesion_names[y_pred[index]]  #predicted label
    label_pred_prob = round(np.max(y_pred_prob[index])*100)
    plt.title('Expected:'+str(label_exp)+'\n Pred.:'+str(label_pred)+' ('+str(label_pred_prob)+'%)')
plt.ylabel('')
plt.tight_layout()
plt.savefig('final_figure.png',dpi=300)
plt.show()

# %%
print('Accuracy for label equal to 0')
print(np.mean(y_test2[y_test2 == 0] == y_pred[y_test2 == 0]))

print('Accuracy for label different from 0')
print(np.mean(y_test2[y_test2 != 0] == y_pred[y_test2 != 0]))
# Out:
# Accuracy for label equal to 0
# 0.8572074107546317
# Accuracy for label different from 0
# 0.9171498321635643

# %%
acc_tot= []

for i in range(7):
    acc_parz = round(np.mean(y_test2[y_test2 == i] == y_pred[y_test2 == i]),2)
    lab_parz = lesion_names[i]
    print('accuracy for',lab_parz,'=',acc_parz)
    acc_tot.append(acc_parz)
# Out:
# accuracy for Melanocytic nevi = 0.86
# accuracy for Melanoma = 0.87
# accuracy for Benign keratosis-like lesions  = 0.92
# accuracy for Basal cell carcinoma = 0.97
# accuracy for Actinic keratoses = 0.92
# accuracy for Vascular lesions = 1.0
# accuracy for Dermatofibroma = 0.96

# %%
acc_tot = np.array(acc_tot)
freq = np.unique(y_test2,return_counts=True)[1]

np.sum(acc_tot*freq)/np.sum(freq)
# Out:
# 0.9016949925858332
